# %%
# Usual stuff, as with previous homework
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('notebook')

import requests

# Maps
import folium

# Geonames requests
from geopy.geocoders import Nominatim

# %%
# Center of Switzerland (according to Wikipedia: https://en.wikipedia.org/wiki/Geographical_centre_of_Switzerland)
ch_map = folium.Map(location=[46.801111, 8.226667])
ch_map.choropleth(geo_path="ch-cantons.topojson.json", topojson="objects.cantons")

# %% [markdown]
# Loading data from CSV
# =====================
#
# We now load the data from the CSV and proceed to convert the amount column to a numeric series in pandas

# %%
projects = pd.read_csv("P3_GrantExport.csv", sep=";", usecols=[6, 7, 13])
frame = pd.DataFrame(projects)
frame = frame.rename(columns={"Approved Amount": "Amount"})
frame.Amount = pd.to_numeric(frame.Amount, errors="coerce")
frame
# Out:
#                                              Institution  \
# 0                                                    NaN
# 1      Faculté de Psychologie et des Sciences de l'Ed...
# 2      Kommission für das Corpus philosophorum medii ...
# 3      Abt. Handschriften und Alte Drucke Bibliothek ...
# 4                           Schweiz. Thesauruskommission
# 5      Séminaire de politique économique, d'économie ...
# 6      Institut für ökumenische Studien Université de...
# 7              Ostasiatisches Seminar Universität Zürich
# 8                                                    NaN
# 9      Laboratoire de Didactique et Epistémologie des...
# 10     Klinische Psychologie und Psychotherapie Insti...
# 11     Schweizerische Rechtsquellen c/o Universität Z...
# 12     Département de Sociologie Faculté des Sciences...
# 13     Institut für Volkswirtschaft WWZ / FGS Univers...
# 14            Soziologisches Institut Universität Zürich
# 15                                 Forschungszentrum FAL
# 16     Faculté de Psychologie et des Sciences de l'Ed...
# 17            Soziologisches Institut Universität Zürich
# 18                                                   NaN
# 19                                                   NaN
# 20     Faculté de Psychologie et des Sciences de l'Ed...
# 21                                                   NaN
# 22     Forschungsbereich Politisches Verhalten und Oe...
# 23     Département des langues et des littératures fr...
# 24                                                   NaN
# 25                                                   NaN
# 26            Schweizerische Gesellschaft für Volkskunde
# 27                         Kuratorium Carl J. Burckhardt
# 28                                                   NaN
# 29     Eidg. Forschungsanstalt für Wald, Schnee und L...
# ...                                                  ...
# 63939  Institut Sozialmanagement und Sozialpolitik Ho...
# 63940                Stiftung Bibliothek Werner Oechslin
# 63941  School of Geographical Sciences University of ...
# 63942                                                NaN
# 63943              CSIRO Marine and Atmospheric Research
# 63944                                                NaN
# 63945     Departement Geographie, SIE Universität Zürich
# 63946  CReAM Department of Economics University Colle...
# 63947                                                NaN
# 63948                                              Eawag
# 63949                      Catholic University of Bukavu
# 63950  Fondation Jean Monnet pour l'Europe Centre de ...
# 63951  Planning of Landscape and Urban Systems Instit...
# 63952  Forschungsanstalt Agroscope Reckenholz-Tänikon...
# 63953  Forschung und Beratung in Wirtschaft und Polit...
# 63954            Zoologisches Institut Universität Basel
# 63955  Zentrum für Religion, Wirtschaft und Politik T...
# 63956  Abteilung für Neuropsychologie Zentrum für Kog...
# 63957                                                NaN
# 63958         Abteilung für Indologie Universität Zürich
# 63959  Institut Religions, Cultures, Modernité FTSR U...
# 63960                                                NaN
# 63961  Department of Physics University of Massachusetts
# 63962                                                NaN
# 63963     Haute École d'art et de design - Genève HES-SO
# 63964  Departement Design Zürcher Hochschule der Küns...
# 63965  Institute Performing Arts and Film Zürcher Hoc...
# 63966  Department of Electrical Engineering and Compu...
# 63967  Département de Biologie Faculté des Sciences U...
# 63968  The Forsyth Institute Department of Microbiolo...
#
#                                               University  Amount
# 0                                   Nicht zuteilbar - NA   11619
# 1                              Université de Genève - GE   41022
# 2                NPO (Biblioth., Museen, Verwalt.) - NPO   79732
# 3                                 Universität Basel - BS   52627
# 4                NPO (Biblioth., Museen, Verwalt.) - NPO  120042
# 5                            Université de Fribourg - FR   53009
# 6                            Université de Fribourg - FR   25403
# 7                                Universität Zürich - ZH   47100
# 8                            Université de Lausanne - LA   25814
# 9                              Université de Genève - GE  360000
# 10                           Université de Fribourg - FR  153886
# 11               NPO (Biblioth., Museen, Verwalt.) - NPO  862200
# 12                             Université de Genève - GE  116991
# 13                                Universität Basel - BS  112664
# 14                               Universität Zürich - ZH    5000
# 15                           Université de Fribourg - FR  204018
# 16                             Université de Genève - GE  149485
# 17                               Universität Zürich - ZH   83983
# 18                                  Nicht zuteilbar - NA   38152
# 19                           Université de Lausanne - LA   14138
# 20                             Université de Genève - GE  164602
# 21                                 Universität Bern - BE  147795
# 22                               Universität Zürich - ZH   24552
# 23                             Université de Genève - GE   44802
# 24                                  Nicht zuteilbar - NA   56000
# 25                                  Nicht zuteilbar - NA  152535
# 26               NPO (Biblioth., Museen, Verwalt.) - NPO  225000
# 27               NPO (Biblioth., Museen, Verwalt.) - NPO  179124
# 28                               Universität Zürich - ZH   20000
# 29     Eidg. Forschungsanstalt für Wald,Schnee,Land -...  445198
# ...                                                  ...     ...
# 63939                           Hochschule Luzern - HSLU    1898
# 63940                                                NaN    9300
# 63941                                                NaN    9500
# 63942                                                NaN    4000
# 63943                                                NaN   11000
# 63944                                                NaN    7500
# 63945                                                NaN    8000
# 63946                                                NaN    9300
# 63947                                                NaN    7000
# 63948                                                NaN    6000
# 63949                                                NaN    4500
# 63950            NPO (Biblioth., Museen, Verwalt.) - NPO    2800
# 63951                                  ETH Zürich - ETHZ   99952
# 63952                Forschungsanstalten Agroscope - AGS   98040
# 63953                       Firmen/Privatwirtschaft - FP  100000
# 63954                                                NaN   10500
# 63955                             Universität Basel - BS   10030
# 63956                                                NaN    7870
# 63957                                                NaN    3150
# 63958                            Universität Zürich - ZH   10600
# 63959                        Université de Lausanne - LA    2515
# 63960                                                NaN    3500
# 63961                                                NaN    4000
# 63962                                                NaN    3550
# 63963                 HES de Suisse occidentale - HES-SO    3000
# 63964             Zürcher Fachhochschule (ohne PH) - ZFH    1000
# 63965             Zürcher Fachhochschule (ohne PH) - ZFH    2000
# 63966                                                NaN   10500
# 63967                                                NaN    9500
# 63968                                                NaN    7000
#
# [63969 rows x 3 columns]

# %% [markdown]
# Filtering the rows
# ==================
#
# Some rows have no information about who got funded so we can't use them to create our map of funding.

# %%
# These have only the Instituion field set so we need to determine their location based on it
not_unis = frame[(frame.University.isnull() & frame.Institution.notnull())] 

# These rows have no location information whatsoever so no need to keep them.
known_unis = frame[(frame.University.notnull()) & (frame.University != "Nicht zuteilbar - NA") & 
                   (frame.University != "NPO (Biblioth., Museen, Verwalt.) - NPO") & 
                  (frame.University != "Firmen/Privatwirtschaft - FP")]

# These rows are for non_profits and private enterprises
non_profits = frame[(frame.University == "NPO (Biblioth., Museen, Verwalt.) - NPO") & (frame.Institution.notnull())]
enterprises = frame[(frame.University == "Firmen/Privatwirtschaft - FP") & (frame.Institution.notnull())]

# %% [markdown]
# Fetching geolocation data
# =========================
#
# We now fetch the geolocation data for each university, non-profit and enterprises in our data.

# %%
# Using google maps API cuz GeoNames can't find shit...
# See here for doc: https://developers.google.com/maps/documentation/geocoding/start
URL = "https://maps.googleapis.com/maps/api/geocode/json"
unique_unis = known_unis.University.unique()

import time 

def extract_canton(res):
    for i in res:
        for data in i["address_components"]:
            if data["types"][0] == "administrative_area_level_1" and data["types"][1] == "political":
                return data["short_name"]
    return None
    
def map_uni_to_canton(name):
    resp = requests.get(URL, params={'address': name, "region": "CH", "key": "AIzaSyC7HdtuwioTklDba6GF3yrjdfbx8p9H37Q"})
    js = resp.json()
    if js["status"] == "OK":
        return extract_canton(js["results"])
    elif js["status"] == "OVER_QUERY_LIMIT":
        print("Time to change the API key!")

def create_mapping_for(places, needs_split=False):
    mapping = {}
    not_found = []
    
    for place in places:
        oldplace = place
        if needs_split: # In case we have the notation "Name - Canton" we need to split
            place = place.split(" -", 1)[0]
            
        canton = map_uni_to_canton(place)
        
        if canton is None:
            not_found.append(oldplace)
        else:
            mapping[oldplace] = canton
    return (mapping, not_found)

# %%
uni_mapping, uni_not_found = create_mapping_for(unique_unis, needs_split=True) 

uni_mapping
# Out:
# {'AO Research Institute - AORI': 'Wien',
#  'Biotechnologie Institut Thurgau - BITG': 'TG',
#  'EPF Lausanne - EPFL': 'VD',
#  'ETH Zürich - ETHZ': 'ZH',
#  'Facoltà di Teologia di Lugano - FTL': 'TI',
#  'Haute école pédagogique BE, JU, NE - HEPBEJUNE': 'NE',
#  'Haute école pédagogique du canton de Vaud - HEPL': 'VD',
#  'Hochschule Luzern - HSLU': 'LU',
#  'Institut für Kulturforschung Graubünden - IKG': 'GR',
#  'Instituto Ricerche Solari Locarno - IRSOL': 'TI',
#  'Interkant. Hochschule für Heilpädagogik ZH - HfH': 'ZH',
#  'Istituto Svizzero di Roma - ISR': 'Lazio',
#  'Kantonsspital St. Gallen - KSPSG': 'SG',
#  'Paul Scherrer Institut - PSI': 'AG',
#  'Physikal.-Meteorolog. Observatorium Davos - PMOD': 'GR',
#  'Pädag. Hochschule Tessin (Teilschule SUPSI) - ASP': 'TI',
#  'Pädagogische Hochschule Bern - PHBern': 'BE',
#  'Pädagogische Hochschule Graubünden - PHGR': 'GR',
#  'Pädagogische Hochschule Luzern - PHLU': 'LU',
#  'Pädagogische Hochschule Schaffhausen - PHSH': 'SH',
#  'Pädagogische Hochschule Schwyz - PHSZ': 'SZ',
#  'Pädagogische Hochschule St. Gallen - PHSG': 'SG',
#  'Pädagogische Hochschule Thurgau - PHTG': 'TG',
#  'Pädagogische Hochschule Wallis - PHVS': 'VS',
#  'Pädagogische Hochschule Zug - PHZG': 'ZG',
#  'Pädagogische Hochschule Zürich - PHZFH': 'ZH',
#  'Robert Walser-Stiftung Bern - RWS': 'BE',
#  'Staatsunabh. Theologische Hochschule Basel - STHB': 'BS',
#  'Universität Basel - BS': 'BS',
#  'Universität Bern - BE': 'BE',
#  'Universität Luzern - LU': 'LU',
#  'Universität St. Gallen - SG': 'SG',
#  'Universität Zürich - ZH': 'ZH',
#  'Université de Fribourg - FR': 'FR',
#  'Université de Genève - GE': 'GE',
#  'Université de Lausanne - LA': 'VD'}

# %%
# Do the same for non profits

unique_npos = non_profits.Institution.unique()

npos_mapping, npos_not_found = create_mapping_for(unique_npos)

# %%
# And for private enterprises

unique_pf = enterprises.Institution.unique()

pf_mapping, pf_not_found = create_mapping_for(unique_pf)

# %%
# We now check how many of these were not successfully matched to a canton

# %%
cantons = ['ZH', 'BE', 'LU', 'UR', 'SZ', 'OW', 'NW', 'GL', 'ZG', 'FR', 
          'SO', 'BS', 'BL', 'SH', 'AR', 'AI', 'SG', 'GR', 'AG', 'TG', 'TI'
          'VD', 'VS', 'NE', 'GE', 'JU', 'CH']

assert len(cantons) == 26

known_unis["Canton"] = known_unis.University.map(uni_mapping)
enterprises["Canton"] = enterprises.Institution.map(pf_mapping)
non_profits["Canton"] = non_profits.Institution.map(npos_mapping)

all_ents = pd.concat([known_unis, enterprises, non_profits])
all_ents
# Out:
# /usr/lib64/python3.4/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/lib64/python3.4/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/lib64/python3.4/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                              Institution  \
# 1      Faculté de Psychologie et des Sciences de l'Ed...
# 3      Abt. Handschriften und Alte Drucke Bibliothek ...
# 5      Séminaire de politique économique, d'économie ...
# 6      Institut für ökumenische Studien Université de...
# 7              Ostasiatisches Seminar Universität Zürich
# 8                                                    NaN
# 9      Laboratoire de Didactique et Epistémologie des...
# 10     Klinische Psychologie und Psychotherapie Insti...
# 12     Département de Sociologie Faculté des Sciences...
# 13     Institut für Volkswirtschaft WWZ / FGS Univers...
# 14            Soziologisches Institut Universität Zürich
# 15                                 Forschungszentrum FAL
# 16     Faculté de Psychologie et des Sciences de l'Ed...
# 17            Soziologisches Institut Universität Zürich
# 19                                                   NaN
# 20     Faculté de Psychologie et des Sciences de l'Ed...
# 21                                                   NaN
# 22     Forschungsbereich Politisches Verhalten und Oe...
# 23     Département des langues et des littératures fr...
# 28                                                   NaN
# 29     Eidg. Forschungsanstalt für Wald, Schnee und L...
# 32        Institut für Iberoromanistik Universität Basel
# 34             Faculté de Théologie Université de Genève
# 38                                                   NaN
# 39     Unité d'anthropologie Département de génétique...
# 40     Faculté de Psychologie et des Sciences de l'Ed...
# 42     Institut für ökumenische Studien Université de...
# 43     Klinische Psychologie und Psychotherapie Insti...
# 44            Soziologisches Institut Universität Zürich
# 45             Universitätsbibliothek Basel Pressestelle
# ...                                                  ...
# 58603  Fondation Guy de Pourtalès Université de Lausanne
# 59645    Gesellschaft für Schweizerische Kunstgeschichte
# 59646    Gesellschaft für Schweizerische Kunstgeschichte
# 59649                              Burgerbibliothek Bern
# 59923                       Stiftung FSMA-HR. Sennhauser
# 59973                        Muséum d'Histoire Naturelle
# 60102         Musée cantonal d'archéologie et d'histoire
# 60156  Fachbereich Mathematik Departement Mathematik ...
# 60439                        Stiftsbibliothek St. Gallen
# 60615                          Jacob Burckhardt-Stiftung
# 60774  Abteilung Geowissenschaften Naturhistorisches ...
# 60980                          Schweizerische Vogelwarte
# 60992   Archäologischer Dienst Graubünden Amt für Kultur
# 61148                                      Sucht Schweiz
# 61178  Foundation for Research on Information Technol...
# 61184                Stiftung Bibliothek Werner Oechslin
# 61185                Stiftung Bibliothek Werner Oechslin
# 61407  Radar, Satellite and Nowcasting Division Meteo...
# 61471  Amt für Städtebau der Stadt Zürich Archäologie...
# 62074    Gesellschaft für Schweizerische Kunstgeschichte
# 62123    Gesellschaft für Schweizerische Kunstgeschichte
# 62124    Gesellschaft für Schweizerische Kunstgeschichte
# 62211  Centre régional d'étude des populations alpine...
# 62431               Office des recherches archéologiques
# 62715   Archäologischer Dienst Graubünden Amt für Kultur
# 63156                        Muséum d'Histoire Naturelle
# 63444  Paul Sacher Stiftung Archiv und Forschungszent...
# 63606                    FORS c/o Université de Lausanne
# 63618                Stiftung Bibliothek Werner Oechslin
# 63950  Fondation Jean Monnet pour l'Europe Centre de ...
#
#                                               University  Amount  \
# 1                              Université de Genève - GE   41022
# 3                                 Universität Basel - BS   52627
# 5                            Université de Fribourg - FR   53009
# 6                            Université de Fribourg - FR   25403
# 7                                Universität Zürich - ZH   47100
# 8                            Université de Lausanne - LA   25814
# 9                              Université de Genève - GE  360000
# 10                           Université de Fribourg - FR  153886
# 12                             Université de Genève - GE  116991
# 13                                Universität Basel - BS  112664
# 14                               Universität Zürich - ZH    5000
# 15                           Université de Fribourg - FR  204018
# 16                             Université de Genève - GE  149485
# 17                               Universität Zürich - ZH   83983
# 19                           Université de Lausanne - LA   14138
# 20                             Université de Genève - GE  164602
# 21                                 Universität Bern - BE  147795
# 22                               Universität Zürich - ZH   24552
# 23                             Université de Genève - GE   44802
# 28                               Universität Zürich - ZH   20000
# 29     Eidg. Forschungsanstalt für Wald,Schnee,Land -...  445198
# 32                                Universität Basel - BS   19134
# 34                             Université de Genève - GE   13807
# 38                          Université de Neuchâtel - NE   51904
# 39                             Université de Genève - GE  462615
# 40                             Université de Genève - GE  143070
# 42                           Université de Fribourg - FR   63684
# 43                                 Universität Bern - BE  154420
# 44                               Universität Zürich - ZH  117564
# 45                                Universität Basel - BS   64279
# ...                                                  ...     ...
# 58603            NPO (Biblioth., Museen, Verwalt.) - NPO   10250
# 59645            NPO (Biblioth., Museen, Verwalt.) - NPO   60000
# 59646            NPO (Biblioth., Museen, Verwalt.) - NPO   55000
# 59649            NPO (Biblioth., Museen, Verwalt.) - NPO   54489
# 59923            NPO (Biblioth., Museen, Verwalt.) - NPO   24010
# 59973            NPO (Biblioth., Museen, Verwalt.) - NPO  169644
# 60102            NPO (Biblioth., Museen, Verwalt.) - NPO   12558
# 60156            NPO (Biblioth., Museen, Verwalt.) - NPO   12200
# 60439            NPO (Biblioth., Museen, Verwalt.) - NPO   15000
# 60615            NPO (Biblioth., Museen, Verwalt.) - NPO  364095
# 60774            NPO (Biblioth., Museen, Verwalt.) - NPO  230218
# 60980            NPO (Biblioth., Museen, Verwalt.) - NPO  429000
# 60992            NPO (Biblioth., Museen, Verwalt.) - NPO    8130
# 61148            NPO (Biblioth., Museen, Verwalt.) - NPO   12000
# 61178            NPO (Biblioth., Museen, Verwalt.) - NPO   10000
# 61184            NPO (Biblioth., Museen, Verwalt.) - NPO    5600
# 61185            NPO (Biblioth., Museen, Verwalt.) - NPO    6400
# 61407            NPO (Biblioth., Museen, Verwalt.) - NPO  558304
# 61471            NPO (Biblioth., Museen, Verwalt.) - NPO    8000
# 62074            NPO (Biblioth., Museen, Verwalt.) - NPO   60000
# 62123            NPO (Biblioth., Museen, Verwalt.) - NPO   42000
# 62124            NPO (Biblioth., Museen, Verwalt.) - NPO   45000
# 62211            NPO (Biblioth., Museen, Verwalt.) - NPO  174149
# 62431            NPO (Biblioth., Museen, Verwalt.) - NPO    5400
# 62715            NPO (Biblioth., Museen, Verwalt.) - NPO   95626
# 63156            NPO (Biblioth., Museen, Verwalt.) - NPO  248000
# 63444            NPO (Biblioth., Museen, Verwalt.) - NPO  244620
# 63606            NPO (Biblioth., Museen, Verwalt.) - NPO    3740
# 63618            NPO (Biblioth., Museen, Verwalt.) - NPO    6400
# 63950            NPO (Biblioth., Museen, Verwalt.) - NPO    2800
#
#                         Canton
# 1                           GE
# 3                           BS
# 5                           FR
# 6                           FR
# 7                           ZH
# 8                           VD
# 9                           GE
# 10                          FR
# 12                          GE
# 13                          BS
# 14                          ZH
# 15                          FR
# 16                          GE
# 17                          ZH
# 19                          VD
# 20                          GE
# 21                          BE
# 22                          ZH
# 23                          GE
# 28                          ZH
# 29                         NaN
# 32                          BS
# 34                          GE
# 38                         NaN
# 39                          GE
# 40                          GE
# 42                          FR
# 43                          BE
# 44                          ZH
# 45                          BS
# ...                        ...
# 58603                       VD
# 59645                      NaN
# 59646                      NaN
# 59649                      NaN
# 59923                      NaN
# 59973  Bourgogne Franche-Comté
# 60102                      NaN
# 60156                       BS
# 60439                       SG
# 60615                      NaN
# 60774                       BS
# 60980                      NaN
# 60992                      NaN
# 61148                      NaN
# 61178                      NaN
# 61184                      NaN
# 61185                      NaN
# 61407                      NaN
# 61471                      NaN
# 62074                      NaN
# 62123                      NaN
# 62124                      NaN
# 62211                      NaN
# 62431                      NaN
# 62715                      NaN
# 63156  Bourgogne Franche-Comté
# 63444                      NaN
# 63606                       VD
# 63618                      NaN
# 63950                      NaN
#
# [48292 rows x 4 columns]

# %%
def verifyResult(df, column="Canton"):
    # Check how many places were not matched to a canton
    null_canton = df[(df.Canton.isnull())]
    
    return null_canton.shape[0] / df.shape[0] * 100
    
print("%.2f%% of places were not matched to a canton" % verifyResult(all_ents))
# Out:
# 12.40% of places were not matched to a canton
